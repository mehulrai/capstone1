# %%
import pandas as pd
import sklearn as sk
import numpy as np
import matplotlib as plt
from sklearn.model_selection import train_test_split
from geopy.distance import geodesic
from pyproj import Geod
import seaborn as sns

# %%
data = pd.read_csv('NYC Taxi Project/test.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9914 entries, 0 to 9913
# Data columns (total 7 columns):
# key                  9914 non-null object
# pickup_datetime      9914 non-null object
# pickup_longitude     9914 non-null float64
# pickup_latitude      9914 non-null float64
# dropoff_longitude    9914 non-null float64
# dropoff_latitude     9914 non-null float64
# passenger_count      9914 non-null int64
# dtypes: float64(4), int64(1), object(2)
# memory usage: 542.2+ KB

# %%
train_data = pd.read_csv('NYC Taxi Project/train.csv')

# %%
#y = train_data.fare_amount
#X = train_data.drop()

# %%
#Testing Train_Test_Split function on sample data

# %%
sample = train_data.head(10000)

# %%
y = sample.fare_amount #Label
X = sample.drop('fare_amount', axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2)

# %%
train_data.info() #info function to figure out the missing data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55423856 entries, 0 to 55423855
# Data columns (total 8 columns):
# key                  object
# fare_amount          float64
# pickup_datetime      object
# pickup_longitude     float64
# pickup_latitude      float64
# dropoff_longitude    float64
# dropoff_latitude     float64
# passenger_count      int64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 3.3+ GB

# %%
sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 8 columns):
# key                  10000 non-null object
# fare_amount          10000 non-null float64
# pickup_datetime      10000 non-null object
# pickup_longitude     10000 non-null float64
# pickup_latitude      10000 non-null float64
# dropoff_longitude    10000 non-null float64
# dropoff_latitude     10000 non-null float64
# passenger_count      10000 non-null int64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 625.1+ KB

# %%
sample.isnull().all() #Missing Data Check
# Out:
# key                  False
# fare_amount          False
# pickup_datetime      False
# pickup_longitude     False
# pickup_latitude      False
# dropoff_longitude    False
# dropoff_latitude     False
# passenger_count      False
# dtype: bool

# %%
train_data.isnull().all() #Missing Data Check on all train data

# %%
sample.head()

# %%
drop_off = (41.499498, -81.695391)
print(geodesic(newport_ri, cleveland_oh).miles)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-5e4426da31b1> in <module>
#       1 drop_off = (41.499498, -81.695391)
# ----> 2 print(geodesic(newport_ri, cleveland_oh).miles)
#
# NameError: name 'newport_ri' is not defined

# %%
pick_up = sample[['pickup_latitude', 'pickup_longitude']]
drop_off = sample[['dropoff_latitude', 'dropoff_longitude']]

# %%
#df_all['MILES'] = df_all.apply((lambda row: vincenty((row['LATITUDE'], 
#row['LONGITUDE']),(row['LAT'], row['LON'])).miles),axis=1)

#sample['distance'] = sample.apply(lambda row: vincenty((row['pickup_latitude'],row['pickup_longitude']),(row['dropoff_latitude'],row['dropoff_longitude'])).miles, axis=1)

#def calculate_distance(row):
#    return row['height'] * row['width']

#rectangles_df.apply(calculate_area, axis=1)

#rectangles_df['area'] = rectangles_df.apply(calculate_area, axis=1)
#rectangles_df

# %%
wgs84_geod = Geod(ellps='WGS84')

# %%
def Distance(lat1,lon1,lat2,lon2):
  az12,az21,dist = wgs84_geod.inv(lon1,lat1,lon2,lat2) #Yes, this order is correct
  return dist

# %%
sample['dist'] = Distance(sample['pickup_latitude'].tolist(),sample['pickup_longitude'].tolist(),sample['dropoff_latitude'].tolist(),sample['dropoff_longitude'].tolist())
# Out:
# c:\python3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
result = sample.loc[:, ['pickup_latitude']]
result1 = sample['pickup_latitude'].tolist()

# %%
result1 = sample.loc[:,['pickup_latitude']]
result2 = sample.loc[:,['pickup_longitude']]
result3 = sample.loc[:,['dropoff_latitude']]
result4 = sample.loc[:,['dropoff_latitude']]

# %%
sample['dist'] = Distance(result1,result2,result3,result4)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\python3\lib\site-packages\pyproj\utils.py in _copytobuffer(x)
#      33                 #  since buffer is modified in place)
# ---> 34                 x.dtype.char
#      35                 # Basemap issue
#
# c:\python3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#
# AttributeError: 'DataFrame' object has no attribute 'dtype'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# c:\python3\lib\site-packages\pyproj\utils.py in _copytobuffer(x)
#      44                     # i don't know Numeric/numarrays has `shape'.
# ---> 45                     x.typecode()
# ...

# %%
sample
# Out:
#                                    key  fare_amount          pickup_datetime  \
# 0          2009-06-15 17:26:21.0000001          4.5  2009-06-15 17:26:21 UTC
# 1          2010-01-05 16:52:16.0000002         16.9  2010-01-05 16:52:16 UTC
# 2         2011-08-18 00:35:00.00000049          5.7  2011-08-18 00:35:00 UTC
# 3          2012-04-21 04:30:42.0000001          7.7  2012-04-21 04:30:42 UTC
# 4        2010-03-09 07:51:00.000000135          5.3  2010-03-09 07:51:00 UTC
# 5          2011-01-06 09:50:45.0000002         12.1  2011-01-06 09:50:45 UTC
# 6          2012-11-20 20:35:00.0000001          7.5  2012-11-20 20:35:00 UTC
# 7         2012-01-04 17:22:00.00000081         16.5  2012-01-04 17:22:00 UTC
# 8        2012-12-03 13:10:00.000000125          9.0  2012-12-03 13:10:00 UTC
# 9         2009-09-02 01:11:00.00000083          8.9  2009-09-02 01:11:00 UTC
# 10         2012-04-08 07:30:50.0000002          5.3  2012-04-08 07:30:50 UTC
# ...
